# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank01/EVA/blob/master/Session10/Assignment10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 10 :  Kernal & Channels Visualization

# %% [markdown]
# ## Pretrained VGG16 Model with GradCAM Integration to Visualize Sunglasses of Tony Stark

# %% [markdown]
# ###Importing and Installing Keras and related core assualts for using in building Neural Network

# %%
import numpy as np 

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Add, BatchNormalization
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('../content/drive/', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at ../content/drive/

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_rows, img_cols, img_channels = train_features.shape
num_test, _, _, _ = test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# ...
# 170500096/170498071 [==============================] - 4s 0us/step

# %% [markdown]
# ##Load Pretrained VGG16 model

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
import cv2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 1. Load helper methods
# 2. Load VGG pretrained Model
# 3. Load cifar10 Image
# 4. Rescaling image to 224*224*3(VGG expectation, y?)
# 5. Use expand_dims to convert image to a batch of size 1
# 6. Preprocessing normalizes our input image by substracting mean RGB values

# %% [markdown]
# ###Test Image from cifar10 Dataset

# %%
model = VGG16(weights="imagenet")
from skimage import io
testimage1 = test_features[9]
testimage1 = cv2.resize(testimage1, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
x = image.img_to_array(testimage1)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0806 18:29:01.211883 139650175338368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0806 18:29:01.498042 139650175338368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0806 18:29:01.510518 139650175338368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# 1. We get the predictions from the image
# 2. We take the topmost class index
# 3. Take output from the final convolution layer

# %% [markdown]
# ###Build GradCam for Layer one (block5_conv2) before  last layer (block5_conv3)

# %%
preds = model.predict(x)
class_idx = np.argmax(preds[0])
print(class_idx)
class_output = model.output[:, class_idx]
print(class_output)
last_conv_layer = model.get_layer("block5_conv2")
print(last_conv_layer)
# Out:
# 675
# Tensor("strided_slice:0", shape=(?,), dtype=float32)
# ...

# %% [markdown]
# 1. Compute the gradient of the class output value with respect to the feature map
# 2. Pool the gradients over all the axies leaving out the channel dimension
# 3. Weigh the output feature map with the computed gradient values

# %%
import keras.backend as K
grads = K.gradients(class_output, last_conv_layer.output)[0]
print(grads.shape)
pooled_grads = K.mean(grads, axis=(0, 1, 2))
print(pooled_grads.shape)
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

pooled_grads_value, conv_layer_output_value = iterate([x])

for i in range(512):
  conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
# Out:
# (?, 14, 14, 512)
# (512,)

# %% [markdown]
# 1. Average the weighted feature map along the channel dimension resulting in a heat map of size 14*14
# 2. Normalize the heatmap to make the value  between 0 and 1

# %%
heatmap = np.mean(conv_layer_output_value, axis=-1)
print(conv_layer_output_value.shape)
print(heatmap.shape)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
# Out:
# (14, 14, 512)
# (14, 14)

# %% [markdown]
# ###Check kernal/Channel Visualization result using GradCam

# %%
heatmap = cv2.resize(heatmap, (testimage1.shape[1], testimage1.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(testimage1, 0.5, heatmap, 0.5, 0)
from google.colab.patches import cv2_imshow
cv2_imshow( testimage1)
cv2_imshow(superimposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0284F495C0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0284985AC8>

# %% [markdown]
# ###GradCAM at a layer one before block5_conv2 i.e block5_conv1

# %%
preds = model.predict(x)
class_idx = np.argmax(preds[0])
print(class_idx)
class_output = model.output[:, class_idx]
last_conv_layer = model.get_layer("block5_conv1")
# Out:
# 675

# %% [markdown]
# ###it identified it as class 675 which is spaceshuttle as per imagenet dataset

# %%
grads = K.gradients(class_output, last_conv_layer.output)[0]
print(grads.shape)
pooled_grads = K.mean(grads, axis=(0, 1, 2))
print(pooled_grads.shape)
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

pooled_grads_value, conv_layer_output_value = iterate([x])

for i in range(512):
  conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
# Out:
# (?, 14, 14, 512)
# (512,)

# %% [markdown]
# ###Heatmap mean from output Convolution layer which helps to max the output with respect to Mean

# %%
heatmap = np.mean(conv_layer_output_value, axis = -1)
print(conv_layer_output_value.shape)
print(heatmap.shape)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
# Out:
# (14, 14, 512)
# (14, 14)

# %% [markdown]
# ###Now Apply GradCam on Heatmap and superImposed Test Image with HeatMap

# %%
heatmap = cv2.resize(heatmap, (testimage1.shape[1], testimage1.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(testimage1, 0.5, heatmap, 0.5, 0)
from google.colab.patches import cv2_imshow
cv2_imshow( testimage1)
cv2_imshow(superimposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0284998CC0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0284998B00>

# %% [markdown]
# ###GradCAM for identifying sunglasses

# %%
model = VGG16(weights="imagenet")
from skimage import io
testimage2 = cv2.imread('../content/drive/My Drive/SOAI/EVA/Session10/16_scale_tony_stark_avenger3_headscrupt_with_glasses.jpg')
testimage2 = cv2.resize(testimage2, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
x = image.img_to_array(testimage2)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
preds = model.predict(x)
class_idx = np.argmax(preds[0])
print(class_idx)
class_output = model.output[:, class_idx]
last_conv_layer = model.get_layer("block5_conv3")
# Out:
# 837

# %% [markdown]
# ###it identified the class as 837 which is sunglasses, dark glasses, shades as per imagenet dataset

# %%
grads = K.gradients(class_output, last_conv_layer.output)[0]
print(grads.shape)
pooled_grads = K.mean(grads, axis=(0, 1, 2))
print(pooled_grads.shape)
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

pooled_grads_value, conv_layer_output_value = iterate([x])

for i in range(512):
  conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
# Out:
# (?, 14, 14, 512)
# (512,)

# %%
heatmap = np.mean(conv_layer_output_value, axis = -1)
print(conv_layer_output_value.shape)
print(heatmap.shape)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
# Out:
# (14, 14, 512)
# (14, 14)

# %%
heatmap = cv2.resize(heatmap, (testimage2.shape[1], testimage2.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(testimage2, 0.5, heatmap, 0.5, 0)
from google.colab.patches import cv2_imshow
cv2_imshow( testimage2)
cv2_imshow(superimposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F02819E9DA0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F02819E9D68>

# %% [markdown]
# ###GradCAM showing the sunglasses region

# %% [markdown]
# ##Part 2 Receptive field calcualtion

# %%
from google.colab.patches import cv2_imshow
RFCalculation = cv2.imread('/content/drive/My Drive/SOAI/EVA/Session10/10B_RF_Session.png')
cv2_imshow( RFCalculation)
# Out:
# <PIL.Image.Image image mode=RGB size=1729x732 at 0x7F6A8E80AC18>

# %% [markdown]
# 1. The network has 1 convolution followed by 3 contracting layers followed by 3 Expanding layers.
# 2. The first convolution is a regular 3x3x3 Conv with stride as 1, using receptive field formula, we get RF as 3x3x3
# 3. Then we have a conv layer with stride as 2, Rf calculation now is 3 + 1*(3-1) = 5
# 4. Now we have a normal conv with stride 1, RF calculation now is 5 + 2*(3-1) = 9
# 5. Then we have a conv layer with stride as 2, Rf calculation now is 9 + 2*(3-1) = 13
# 6. Now we have a normal conv with stride 1, RF calculation now is 13 + 4*(3-1) = 21
# 7. Then we have a conv layer with stride as 2, Rf calculation now is 21 + 4*(3-1) = 29
# 8. Now we have a normal conv with stride 1, RF calculation now is 29 + 8 * (3-1) = 4
